# %% [markdown]
# <a href="https://colab.research.google.com/github/whuera/ds-analisis-datos/blob/master/T1M4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/ejemplo01.csv", sep = ";")

# %%
df.head()
# Out:
#    Nombre  Evaluacion Matematicas  Evaluacion Lenguaje
# 0  Javier                     5.0                    8
# 1   Marta                     7.0                    9
# 2   Lucia                     8.0                    7
# 3   Pedro                     4.0                    5
# 4    Juan                    10.0                    8

# %%
df['Evaluacion Lenguaje'].sum()
# Out:
# 43

# %%
df['Evaluacion Lenguaje'].mean()
# Out:
# 7.166666666666667

# %%
df['Evaluacion Lenguaje'].min()
# Out:
# 5

# %%
df['Evaluacion Lenguaje'].max()
# Out:
# 9

# %%
df['Evaluacion Lenguaje'].quantile(0.8)
# Out:
# 8.0

# %%
df.describe()
# Out:
#        Evaluacion Matematicas  Evaluacion Lenguaje
# count                5.000000             6.000000
# mean                 6.800000             7.166667
# std                  2.387467             1.471960
# min                  4.000000             5.000000
# 25%                  5.000000             6.250000
# 50%                  7.000000             7.500000
# 75%                  8.000000             8.000000
# max                 10.000000             9.000000

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/ds_train.csv", encoding = "ISO-8859-1", delimiter = ",")

# %%
df.head()
# Out:
#                                          PassengerId  Survived  Pclass  Name  \
# 0  1,0,3,"Braund, Mr. Owen Harris",male,22,1,0,A/...       NaN     NaN   NaN
# 1  2,1,1,"Cumings, Mrs. John Bradley (Florence Br...       NaN     NaN   NaN
# 2  3,1,3,"Heikkinen, Miss. Laina",female,26,0,0,S...       NaN     NaN   NaN
# 3  4,1,1,"Futrelle, Mrs. Jacques Heath (Lily May ...       NaN     NaN   NaN
# 4  5,0,3,"Allen, Mr. William Henry",male,35,0,0,3...       NaN     NaN   NaN
#
#    Sex  Age  SibSp  Parch  Ticket  Fare  Cabin  Embarked
# 0  NaN  NaN    NaN    NaN     NaN   NaN    NaN       NaN
# 1  NaN  NaN    NaN    NaN     NaN   NaN    NaN       NaN
# 2  NaN  NaN    NaN    NaN     NaN   NaN    NaN       NaN
# 3  NaN  NaN    NaN    NaN     NaN   NaN    NaN       NaN
# 4  NaN  NaN    NaN    NaN     NaN   NaN    NaN       NaN

# %%
df1 = pd.read_csv("/content/dstrain.csv", encoding = "ISO-8859-1", delimiter = ",")

# %%
df1.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(df1["Sex"], df1["Survived"])

# %%
import numpy as np

# %%
df1.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df_survived = df1[(df1["Survived"] == 1)]
df_survived.head(50)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 55            56         1       1
# ...

# %%
df_rename = df_survived.rename(columns = {"Cabin": "Tripulacion de Cabina"})

# %%
df_rename.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 15           16         1       2
# 17           18         1       2
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# ...

# %%
df_filter_cabin = df_rename[(df_rename["Tripulacion de Cabina"].notnull())]

# %%
df_filter_cabin.head(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 31            32         1       1
# 52            53         1       1
# 55            56         1       1
# 61            62         1       1
# 66            67         1       2
# 88            89         1       1
# 97            98         1       1
# 123          124         1       2
# 128          129         1       3
# 136          137         1       1
# 151          152         1       1
# 166          167         1       1
# 183          184         1       2
# 193          194         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df_count_cabin = df_rename.dropna(subset = ["Tripulacion de Cabina"])

# %%
df_count_cabin.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 10           11         1       3
# 11           12         1       1
# 21           22         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
#
#     Parch    Ticket     Fare Tripulacion de Cabina Embarked
# 1       0  PC 17599  71.2833                   C85        C
# 3       0    113803  53.1000                  C123        S
# 10      1   PP 9549  16.7000                    G6        S
# 11      0    113783  26.5500                  C103        S
# ...

# %%
df_count_cabin = df_count_cabin["Survived"].sum()

# %%
print("valor sobrevivientes de cabina: ",df_count_cabin)
# Out:
# valor sobrevivientes de cabina:  136

# %%
df_filter_cabin["Age"].unique()
# Out:
# array([38.  , 35.  ,  4.  , 58.  , 34.  , 28.  ,   nan, 49.  , 29.  ,
#        23.  , 32.5 , 19.  , 22.  ,  1.  ,  3.  , 44.  , 40.  , 31.  ,
#        32.  , 37.  , 30.  , 63.  , 50.  ,  0.92, 17.  , 24.  , 18.  ,
#        36.  , 16.  , 41.  ,  2.  , 60.  , 25.  , 33.  , 14.  , 52.  ,
#        48.  , 54.  , 39.  , 53.  , 42.  , 21.  , 80.  , 56.  , 27.  ,
#        15.  ,  6.  , 51.  , 43.  , 11.  , 62.  , 47.  , 26.  ])

# %%
df_filter_cabin["Age"] = np.where(df_filter_cabin["Age"].isnull(), 0, df_filter_cabin["Age"])

# %%
df_filter_cabin.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 10           11         1       3
# 11           12         1       1
# 21           22         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
#
#     Parch    Ticket     Fare Tripulacion de Cabina Embarked
# 1       0  PC 17599  71.2833                   C85        C
# 3       0    113803  53.1000                  C123        S
# 10      1   PP 9549  16.7000                    G6        S
# 11      0    113783  26.5500                  C103        S
# ...

# %%
df_filter_cabin["Age"].unique()
# Out:
# array([38.  , 35.  ,  4.  , 58.  , 34.  , 28.  ,  0.  , 49.  , 29.  ,
#        23.  , 32.5 , 19.  , 22.  ,  1.  ,  3.  , 44.  , 40.  , 31.  ,
#        32.  , 37.  , 30.  , 63.  , 50.  ,  0.92, 17.  , 24.  , 18.  ,
#        36.  , 16.  , 41.  ,  2.  , 60.  , 25.  , 33.  , 14.  , 52.  ,
#        48.  , 54.  , 39.  , 53.  , 42.  , 21.  , 80.  , 56.  , 27.  ,
#        15.  ,  6.  , 51.  , 43.  , 11.  , 62.  , 47.  , 26.  ])

# %%
df_rename_fare = df_rename.rename(columns = {"Fare": "Tarifa"})

# %%
df_rename_fare
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_rename_fare["tax_estandarizado"] = (df_rename_fare["Tarifa"] - np.mean(df_rename_fare["Tarifa"])) / np.std(df_rename_fare["Tarifa"])

# %%
df_rename_fare
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_rename_fare.describe()
# Out:
#        PassengerId  Survived      Pclass         Age       SibSp       Parch  \
# count   342.000000     342.0  342.000000  290.000000  342.000000  342.000000
# mean    444.368421       1.0    1.950292   28.343690    0.473684    0.464912
# std     252.358840       0.0    0.863321   14.950952    0.708688    0.771712
# min       2.000000       1.0    1.000000    0.420000    0.000000    0.000000
# 25%     250.750000       1.0    1.000000   19.000000    0.000000    0.000000
# 50%     439.500000       1.0    2.000000   28.000000    0.000000    0.000000
# 75%     651.500000       1.0    3.000000   36.000000    1.000000    1.000000
# max     890.000000       1.0    3.000000   80.000000    4.000000    5.000000
#
#            Tarifa  tax_estandarizado
# count  342.000000       3.420000e+02
# mean    48.395408      -2.597013e-17
# std     66.596998       1.001465e+00
# min      0.000000      -7.277553e-01
# 25%     12.475000      -5.401601e-01
# 50%     26.000000      -3.367753e-01
# ...

# %%
import numpy as np, pandas as pd

# %%
import matplotlib.pyplot as plt, seaborn as snb

# %%
import datetime, os

# %%
df_iris = pd.read_csv("/content/Iris.csv", encoding = "ISO-8859-1", delimiter = ",")

# %%
df_iris.head(50)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df_iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df_iris["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df_iris.groupby('Species').mean()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %%
fig, ax = plt.subplots()
ax.plot(
    df_iris.index,
    df_iris['Species'],
    label='Especies'
)
ax.plot(
    df_iris.index,
    df_iris['SepalLengthCm'],
    label='Longitud de Separacion'
)
ax.legend()

# %%
df_iris.head(10)

# %%
df_iris.groupby('Species').mean()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %%
fig, ax = plt.subplots()
ax.scatter(x = df_iris['Species'], y = df_iris["PetalLengthCm"], edgecolors='red', c='green')

# %%
data = {
    "SepalLengthCm" : [5.1, 4.9, 4.7],
    "PetalLengthCm" : [1.4, 1.4, 1.3],
    "Species" : ["Iris-setosa", "Iris-versicolor	", "Iris-virginica"]
}
df = pd.DataFrame(data, columns=['SepalLengthCm', 'SepalWidthCm'], index = data['Species'])
df.head()
fig, ax = plt.subplots()
ax.plot(df)
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fig, ax1 = plt.subplots()
ax1.scatter(x = df['SepalLengthCm'], y = df["SepalLengthCm"], edgecolors='red', c='green')
#ax1.plot(df.index, df['SepalWidthCm'])

# %%
import numpy as np, pandas as pd
import matplotlib.pyplot as plt, seaborn as snb

# %%
df_iris = pd.read_csv('/content/Iris.csv')

# %%
df_iris.shape
# Out:
# (150, 6)

# %%
df_iris.head(50)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df_iris.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df_iris.dtypes
snb.countplot(x = 'Species', data = df_iris)
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
df_iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
df_iris['Species'].value_counts().plot(kind='pie', autopct="%1.2f%%")
# Out:
# <Axes: ylabel='Species'>

# %%
df_iris['Species'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df_iris['Species'].value_counts().plot.hist()
plt.show()

# %%
df_iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
snb.distplot(df_iris['PetalWidthCm'])
# Out:
# <ipython-input-25-9d5bc7c2e94e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   snb.distplot(df_iris['PetalWidthCm'])
# <Axes: xlabel='PetalWidthCm', ylabel='Density'>

# %%
snb.scatterplot(x = df_iris['PetalWidthCm'], y=df_iris['SepalWidthCm'])
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='SepalWidthCm'>

# %%
snb.scatterplot(
    x='PetalWidthCm',
    y='SepalWidthCm',
    data = df_iris,
    palette='bright',
    hue='Species'
);

# %%
snb.jointplot(
    x='PetalWidthCm',
    y='SepalWidthCm',
    data = df_iris,
    palette='bright',
    hue='Species'
);

# %%
snb.catplot(
    x='Species',
    y='SepalWidthCm',
    data = df_iris,
    palette='bright',
    hue='PetalWidthCm',
    col='PetalWidthCm',
    col_wrap=2
);

# %%
snb.boxplot(
    x='PetalWidthCm',
    y='SepalWidthCm',
    data = df_iris
);

# %%
snb.pairplot(df_iris)
